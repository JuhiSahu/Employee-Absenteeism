# %%
import os
os.chdir("C:/Users/dell/Desktop/edWisor Stuff/Project1")

# %%
import pandas as pd
import numpy as np
# %matplotlib 
import matplotlib.pyplot as plt
# Out:
# Using matplotlib backend: Qt5Agg

# %%
df = pd.read_excel("Absenteeism_at_work_Project.xls")
data1 = pd.DataFrame(df)

# %%
data1.shape
# Out:
# (740, 21)

# %%
data1.head(10)
# Out:
#    ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0  11                26.0               7.0                3        1
# 1  36                 0.0               7.0                3        1
# 2   3                23.0               7.0                4        1
# 3   7                 7.0               7.0                5        1
# 4  11                23.0               7.0                5        1
# 5   3                23.0               7.0                6        1
# 6  10                22.0               7.0                6        1
# 7  20                23.0               7.0                6        1
# 8  14                19.0               7.0                2        1
# 9   1                22.0               7.0                2        1
#
#    Transportation expense  Distance from Residence to Work  Service time  \
# 0                   289.0                             36.0          13.0
# ...

# %%
#changingg data types
data1['Reason for absence'] = data1['Reason for absence'].astype('object')
data1['Month of absence'] = data1['Month of absence'].astype('object')
data1['Day of the week'] = data1['Day of the week'].astype('object')
data1['Seasons'] = data1['Seasons'].astype('object')
data1['Disciplinary failure'] = data1['Disciplinary failure'].astype('object')
data1['Education'] = data1['Education'].astype('object')
data1['Social drinker'] = data1['Social drinker'].astype('object')
data1['Social smoker'] = data1['Social smoker'].astype('object')

# %%
#missing value analysis
data1.isnull().sum()
# Out:
# ID                                  0
# Reason for absence                  3
# Month of absence                    1
# Day of the week                     0
# Seasons                             0
# Transportation expense              7
# Distance from Residence to Work     3
# Service time                        3
# Age                                 3
# Work load Average/day              10
# Hit target                          6
# Disciplinary failure                6
# Education                          10
# Son                                 6
# Social drinker                      3
# Social smoker                       4
# Pet                                 2
# Weight                              1
# Height                             14
# Body mass index                    31
# Absenteeism time in hours          22
# dtype: int64

# %%
sum(data1.isnull().sum()) / len(data1)
# Out:
# 0.18243243243243243

# %%
#treating col2 
data1.loc[data1['Reason for absence'] == 0, ['Reason for absence']] = 26
data1['Reason for absence'] = data1['Reason for absence'].fillna(data1['Reason for absence'].median())

# %%
#treating col18
data1['Weight'] = data1['Weight'].fillna(data1['Weight'].mean())

# %%
#treating col19
data1['Height'] = data1['Height'].fillna(data1['Height'].mean())

# %%
#treating col20
data1['Body mass index'] = data1['Body mass index'].fillna((data1['Weight']*10000)/data1['Height']**2)

# %%
#treating col6
data1['Distance from Residence to Work'] = data1['Distance from Residence to Work'].fillna(data1['Distance from Residence to Work'].median())

# %%
#treating col7
data1['Transportation expense'] = data1['Transportation expense'].fillna(data1['Transportation expense'].median())

# %%
data1['Service time'] = data1['Service time'].fillna(data1['Service time'].median())

# %%
data1['Work load Average/day '] = data1['Work load Average/day '].fillna(data1['Work load Average/day '].median())

# %%
data1['Age'] = data1['Age'].fillna(data1['Age'].mean())

# %%
data1['Hit target'] = data1['Hit target'].fillna(data1['Hit target'].mean())

# %%
data1['Absenteeism time in hours'] = data1['Absenteeism time in hours'].fillna(data1['Absenteeism time in hours'].mean())

# %%
data1['Month of absence'] = data1['Month of absence'].fillna(data1['Month of absence'].median())

# %%
data1['Disciplinary failure'] = data1['Disciplinary failure'].fillna(data1['Disciplinary failure'].median())

# %%
data1['Education'] = data1['Education'].fillna(data1['Education'].median())

# %%
data1['Son'] = data1['Son'].fillna(data1['Son'].median())

# %%
data1['Social drinker'] = data1['Social drinker'].fillna(data1['Social drinker'].median())

# %%
data1['Social smoker'] = data1['Social smoker'].fillna(data1['Social smoker'].median())

# %%
data1['Pet'] = data1['Pet'].fillna(data1['Pet'].median())

# %%
#knnImputation
#from fancyimpute import KNN ni chaling

# %%
#VISVUALIZATION

# %%
#OUTLIERS

#create copy
copy1 = data1.copy()

# %%
copy1
# Out:
#      ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0    11                26.0               7.0                3        1
# 1    36                26.0               7.0                3        1
# 2     3                23.0               7.0                4        1
# 3     7                 7.0               7.0                5        1
# 4    11                23.0               7.0                5        1
# 5     3                23.0               7.0                6        1
# 6    10                22.0               7.0                6        1
# 7    20                23.0               7.0                6        1
# 8    14                19.0               7.0                2        1
# 9     1                22.0               7.0                2        1
# 10   20                 1.0               7.0                2        1
# 11   20                 1.0               7.0                3        1
# ...

# %%
numeric = data1[['Transportation expense', 'Distance from Residence to Work',
                  'Service time', 'Age', 'Work load Average/day ', 'Hit target','Son','Pet', 
                  'Weight', 'Height', 'Body mass index','Absenteeism time in hours']]

# %%
#plot boxplot
# %matplotlib inline

# %%
plt.boxplot(data1['Transportation expense'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0xb202828>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0xb217128>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0xb2026d8>],
#  'medians': [<matplotlib.lines.Line2D at 0xb217978>],
#  'fliers': [<matplotlib.lines.Line2D at 0xb217da0>],
#  'means': []}

# %%
#Replace Transportation expense outliers with NA
#Extract quartiles
q75, q25 = np.percentile(data1['Transportation expense'], [75 ,25])

#Calculate IQR
iqr = q75 - q25

#Calculate inner and outer fence
minimum = q25 - (iqr*1.5)
maximum = q75 + (iqr*1.5)

#Replace with NA
data1.loc[data1['Transportation expense'] < minimum,:'Transportation expense'] = np.nan
data1.loc[data1['Transportation expense'] > maximum,:'Transportation expense'] = np.nan

# %%
plt.boxplot(data1['Distance from Residence to Work'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x96e3978>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x96eb278>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x96e3828>],
#  'medians': [<matplotlib.lines.Line2D at 0x96ebac8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x96ebef0>],
#  'means': []}

# %%
plt.boxplot(data1['Service time'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x9739e10>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x9744710>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x9739cc0>],
#  'medians': [<matplotlib.lines.Line2D at 0x9744f60>],
#  'fliers': [<matplotlib.lines.Line2D at 0x974c3c8>],
#  'means': []}

# %%
#Detect Service time outliers with NA
#Extract quartiles
q75, q25 = np.percentile(data1['Service time'], [75 ,25])

#Calculate IQR
iqr = q75 - q25

#Calculate inner and outer fence
minimum = q25 - (iqr*1.5)
maximum = q75 + (iqr*1.5)

#Replace with NA
data1.loc[data1['Service time'] < minimum,:'Service time'] = np.nan
data1.loc[data1['Service time'] > maximum,:'Service time'] = np.nan

# %%
plt.boxplot(data1['Age'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x80f3fd0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x80f3710>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x80f3160>],
#  'medians': [<matplotlib.lines.Line2D at 0x978b240>],
#  'fliers': [<matplotlib.lines.Line2D at 0x978b668>],
#  'means': []}

# %%
#Detect and replace with NA
#Extract quartiles
q75, q25 = np.percentile(data1['Age'], [75 ,25])

#Calculate IQR
iqr = q75 - q25

#Calculate inner and outer fence
minimum = q25 - (iqr*1.5)
maximum = q75 + (iqr*1.5)

#Replace with NA
data1.loc[data1['Age'] < minimum,:'Age'] = np.nan
data1.loc[data1['Age'] > maximum,:'Age'] = np.nan

# %%
plt.boxplot(data1['Work load Average/day '])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x8162898>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x816f208>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x8162748>],
#  'medians': [<matplotlib.lines.Line2D at 0x816f9e8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x816fe10>],
#  'means': []}

# %%
#Detect and replace with NA
#Extract quartiles
q75, q25 = np.percentile(data1['Work load Average/day '], [75 ,25])

#Calculate IQR
iqr = q75 - q25

#Calculate inner and outer fence
minimum = q25 - (iqr*1.5)
maximum = q75 + (iqr*1.5)

#Replace with NA
data1.loc[data1['Work load Average/day '] < minimum,:'Work load Average/day '] = np.nan
data1.loc[data1['Work load Average/day '] > maximum,:'Work load Average/day '] = np.nan

# %%
plt.boxplot(data1['Body mass index'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x97a9a20>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x97b1390>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x97a98d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x97b1b70>],
#  'fliers': [<matplotlib.lines.Line2D at 0x97b1f98>],
#  'means': []}

# %%
plt.boxplot(data1['Hit target'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x9809860>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x9813160>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x9809710>],
#  'medians': [<matplotlib.lines.Line2D at 0x98139b0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x9813dd8>],
#  'means': []}

# %%
#Detect and replace with NA
#Extract quartiles
q75, q25 = np.percentile(data1['Hit target'], [75 ,25])

#Calculate IQR
iqr = q75 - q25

#Calculate inner and outer fence
minimum = q25 - (iqr*1.5)
maximum = q75 + (iqr*1.5)

#Replace with NA
data1.loc[data1['Hit target'] < minimum,:'Hit target'] = np.nan
data1.loc[data1['Hit target'] > maximum,:'Hit target'] = np.nan

# %%
plt.boxplot(data1['Absenteeism time in hours'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0xa838710>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0xa838fd0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0xa8385c0>],
#  'medians': [<matplotlib.lines.Line2D at 0xa841860>],
#  'fliers': [<matplotlib.lines.Line2D at 0xa841c88>],
#  'means': []}

# %%
#Detect and replace with NA
#Extract quartiles
q75, q25 = np.percentile(data1['Absenteeism time in hours'], [75 ,25])

#Calculate IQR
iqr = q75 - q25

#Calculate inner and outer fence
minimum = q25 - (iqr*1.5)
maximum = q75 + (iqr*1.5)

#Replace with NA
data1.loc[data1['Absenteeism time in hours'] < minimum,:'Absenteeism time in hours'] = np.nan
data1.loc[data1['Absenteeism time in hours'] > maximum,:'Absenteeism time in hours'] = np.nan

# %%
#Impute replaced outliers
data1['Transportation expense'] = data1['Transportation expense'].fillna(data1['Transportation expense'].median())
data1['Service time']= data1['Service time'].fillna(data1['Service time'].median())
data1['Height']= data1['Height'].fillna(data1['Height'].median())
data1['Pet']= data1['Pet'].fillna(data1['Pet'].median())
data1['Hit target']= data1['Hit target'].fillna(data1['Hit target'].median())
data1['Age'] = data1['Age'].fillna(data1['Age'].median())
data1['Work load Average/day ']= data1['Work load Average/day '].fillna(data1['Work load Average/day '].median())
data1['Absenteeism time in hours']= data1['Absenteeism time in hours'].fillna(data1['Absenteeism time in hours'].median())

# %%
data1['ID'] = copy1['ID']
data1['Reason for absence'] = copy1['Reason for absence']
data1['Month of absence'] = copy1['Month of absence']
data1['Day of the week'] = copy1['Day of the week']
data1['Seasons'] = copy1['Seasons']
data1['Distance from Residence to Work'] = copy1['Distance from Residence to Work']
data1['Disciplinary failure'] = copy1['Disciplinary failure']
data1['Education'] = copy1['Education']
data1['Son'] = copy1['Son']
data1['Social drinker'] = copy1['Social drinker']
data1['Social smoker'] = copy1['Social smoker']
data1['Weight'] = copy1['Weight']
data1['Body mass index'] =  copy1['Body mass index']

# %%
#converting datatypes
data1['ID'] = data1['ID'].astype('category')
data1['Reason for absence'] = data1['Reason for absence'].astype('category')
data1['Month of absence'] = data1['Month of absence'].astype('category')
data1['Day of the week'] = data1['Day of the week'].astype('category')
data1['Seasons'] = data1['Seasons'].astype('category')
data1['Disciplinary failure'] = data1['Disciplinary failure'].astype('category')
data1['Education'] = data1['Education'].astype('category')
data1['Social drinker'] = data1['Social drinker'].astype('category')
data1['Social smoker'] = data1['Social smoker'].astype('category')
data1['Age'] = data1['Age'].astype('int')
data1['Son'] = data1['Son'].astype('int')
data1['Pet'] = data1['Pet'].astype('int')

# %%
data1.dtypes
# Out:
# ID                                 category
# Reason for absence                 category
# Month of absence                   category
# Day of the week                    category
# Seasons                            category
# Transportation expense              float64
# Distance from Residence to Work     float64
# Service time                        float64
# Age                                   int32
# Work load Average/day               float64
# Hit target                          float64
# Disciplinary failure               category
# Education                          category
# Son                                   int32
# Social drinker                     category
# Social smoker                      category
# Pet                                   int32
# Weight                              float64
# Height                              float64
# Body mass index                     float64
# Absenteeism time in hours           float64
# dtype: object

# %%
data1.head(5)
# Out:
#    ID Reason for absence Month of absence Day of the week Seasons  \
# 0  11               26.0              7.0               3       1
# 1  36               26.0              7.0               3       1
# 2   3               23.0              7.0               4       1
# 3   7                7.0              7.0               5       1
# 4  11               23.0              7.0               5       1
#
#    Transportation expense  Distance from Residence to Work  Service time  Age  \
# 0                   289.0                             36.0          13.0   33
# 1                   118.0                             13.0          18.0   50
# 2                   179.0                             51.0          18.0   38
# 3                   279.0                              5.0          14.0   39
# 4                   289.0                             36.0          13.0   33
#
#    Work load Average/day             ...              Disciplinary failure  \
# ...

# %%
#FEATURE SELECTION

numeric = data1[['Transportation expense', 'Distance from Residence to Work',
                  'Service time', 'Age', 'Work load Average/day ', 'Hit target','Son','Pet', 
                  'Weight', 'Height', 'Body mass index','Absenteeism time in hours']]

# %%
numeric.shape
# Out:
# (740, 12)

# %%
#Set the width and hieght of the plot
f, ax = plt.subplots(figsize=(10,8))

# %%
#correlation plot
corr = numeric.corr()

# %%
#Plot using seaborn library
import seaborn as sns
# %matplotlib inline
sns.heatmap(corr, mask=np.zeros_like(corr, dtype=np.bool), cmap= sns.diverging_palette(220,10,as_cmap=True),annot=True,
            square=True, ax=ax)

# %%
corr
# Out:
#                                  Transportation expense  \
# Transportation expense                         1.000000
# Distance from Residence to Work                0.256591
# Service time                                  -0.347613
# Age                                           -0.227396
# Work load Average/day                          0.000411
# Hit target                                    -0.080497
# Son                                            0.378563
# Pet                                            0.394313
# Weight                                        -0.209143
# Height                                        -0.193099
# Body mass index                               -0.136393
# Absenteeism time in hours                      0.045890
#
#                                  Distance from Residence to Work  \
# Transportation expense                                  0.256591
# Distance from Residence to Work                         1.000000
# ...

# %%
sns.pairplot(data1)

# %%
data1.groupby(["ID", "Absenteeism time in hours"]).size().unstack().plot(kind='bar', stacked=True, figsize=(10,10))

# %%
data1.groupby(["Reason for absence", "Absenteeism time in hours"]).size().unstack().plot(kind='bar', stacked=True, figsize=(10,10))

# %%
data1.groupby(["Month of absence", "Absenteeism time in hours"]).size().unstack().plot(kind='bar', stacked=True, figsize=(10,10))

# %%
data1.groupby(["Day of the week", "Absenteeism time in hours"]).size().unstack().plot(kind='bar', stacked=True, figsize=(10,10))

# %%
data1.groupby(["Education", "Absenteeism time in hours"]).size().unstack().plot(kind='bar', stacked=True, figsize=(10,10))
#company shoud employ

# %%
data1.groupby(["Disciplinary failure", "Absenteeism time in hours"]).size().unstack().plot(kind='bar', stacked=True, figsize=(10,10))

# %%
data1.groupby(["Social drinker", "Absenteeism time in hours"]).size().unstack().plot(kind='bar', stacked=True, figsize=(10,10))

# %%
data1.groupby(["Social smoker", "Absenteeism time in hours"]).size().unstack().plot(kind='bar', stacked=True, figsize=(10,10))

# %%
data1.groupby(["Transportation expense", "Absenteeism time in hours"]).size().unstack().plot(kind='bar', stacked=True, figsize=(10,10))

# %%
data1.head(2)
# Out:
#   Reason for absence Month of absence Day of the week Seasons  \
# 0               26.0              7.0               3       1
# 1               26.0              7.0               3       1
#
#    Transportation expense  Service time  Age  Work load Average/day   \
# 0                   289.0          13.0   33                239554.0
# 1                   118.0          18.0   50                239554.0
#
#    Hit target Disciplinary failure Education  Son Social drinker  \
# 0        97.0                  0.0       1.0    2            1.0
# 1        97.0                  1.0       1.0    1            1.0
#
#   Social smoker  Pet  Body mass index  Absenteeism time in hours
# 0           0.0    1             30.0                        4.0
# 1           0.0    0             31.0                        0.0

# %%
data1.dtypes
# Out:
# Reason for absence           category
# Month of absence             category
# Day of the week              category
# Seasons                      category
# Transportation expense        float64
# Service time                  float64
# Age                             int32
# Work load Average/day         float64
# Hit target                    float64
# Disciplinary failure         category
# Education                    category
# Son                             int32
# Social drinker               category
# Social smoker                category
# Pet                             int32
# Body mass index               float64
# Absenteeism time in hours     float64
# dtype: object

# %%
#Droppong variables
data1 = data1.drop(['ID','Height','Weight','Distance from Residence to Work'], axis=1)

# %%
#ANOVA TEST
from scipy import stats

# %%
#Reason for absence 
grps2 = pd.unique(data1['Reason for absence'].values)
d_data = {grp:data1['Absenteeism time in hours'][data1['Reason for absence'] == grp] for grp in grps2}
k= len(pd.unique(data1['Reason for absence']))
N = len(data1.values)
n = data1.groupby('Reason for absence').size()[0]

f,p = stats.f_oneway(d_data[1.0], d_data[2.0], d_data[3.0], d_data[4.0], d_data[5.0], d_data[6.0], d_data[7.0], d_data[8.0], d_data[9.0], d_data[10.0],
                     d_data[11.0], d_data[12.0], d_data[13.0], d_data[14.0], d_data[15.0], d_data[16.0], d_data[17.0], d_data[18.0], d_data[19.0], d_data[21.0],
                     d_data[22.0], d_data[23.0], d_data[24.0], d_data[25.0], d_data[26.0], d_data[27.0], d_data[28.0])

f,p 

#f = 10.14
#p = 3.21
# Out:
# (10.148823181435771, 3.2178699886939187e-34)

# %%
#Month of absence
grps2 = pd.unique(data1['Month of absence'].values)
d_data = {grp:data1['Absenteeism time in hours'][data1['Month of absence'] == grp] for grp in grps2}
k= len(pd.unique(data1['Month of absence']))
N = len(data1.values)
n = data1.groupby('Month of absence').size()[0]

f,p = stats.f_oneway(d_data[0.0], d_data[1.0], d_data[2.0], d_data[3.0], d_data[4.0], d_data[5.0], d_data[6.0], d_data[7.0], d_data[8.0], d_data[9.0], d_data[10.0],
                     d_data[11.0], d_data[12.0])

f,p 

#f = 2.35
#p = 0.005
# Out:
# (2.3585430737617616, 0.0056154888628179266)

# %%
#Day of the week
grps2 = pd.unique(data1['Day of the week'].values)
d_data = {grp:data1['Absenteeism time in hours'][data1['Day of the week'] == grp] for grp in grps2}
k= len(pd.unique(data1['Day of the week']))
N = len(data1.values)
n = data1.groupby('Day of the week').size()[0]

f,p = stats.f_oneway(d_data[2], d_data[3], d_data[4], d_data[5], d_data[6])

f,p 

#f = 0.99
#p = 0.41
# Out:
# (0.9934314346902466, 0.4102982119887095)

# %%
#Seasons 
grps = pd.unique(data1.Seasons.values)
d_data = {grp:data1['Absenteeism time in hours'][data1.Seasons == grp] for grp in grps}
k= len(pd.unique(data1.Seasons))
N = len(data1.values)
n = data1.groupby('Seasons').size()[0]

f,p = stats.f_oneway(d_data[1], d_data[4], d_data[2], d_data[3])

f,p 

#f= 0.89
#p = 0.44

# %%
#Disciplinary failure
grps2 = pd.unique(data1['Disciplinary failure'].values)
d_data = {grp:data1['Absenteeism time in hours'][data1['Disciplinary failure'] == grp] for grp in grps2}
k= len(pd.unique(data1['Disciplinary failure']))
N = len(data1.values)
n = data1.groupby('Disciplinary failure').size()[0]

f,p = stats.f_oneway(d_data[0.0], d_data[1.0])

f,p 

#f = 38.90
#p = 7.49
# Out:
# (38.902708977352454, 7.498401861453567e-10)

# %%
#Education
grps = pd.unique(data1.Education.values)
d_data = {grp:data1['Absenteeism time in hours'][data1.Education == grp] for grp in grps}
k= len(pd.unique(data1.Education))
N = len(data1.values)
n = data1.groupby('Education').size()[0]

f,p = stats.f_oneway(d_data[1.0], d_data[2.0], d_data[3.0], d_data[4.0])

f,p 

#f = 1.07
#p = 0.35
# Out:
# (1.0729351492287522, 0.35979740261976295)

# %%
#Social drinker
grps = pd.unique(data1['Social drinker'].values)
d_data = {grp:data1['Absenteeism time in hours'][data1['Social drinker'] == grp] for grp in grps}
k= len(pd.unique(data1['Social drinker']))
N = len(data1.values)
n = data1.groupby('Social drinker').size()[0]

f,p = stats.f_oneway(d_data[1.0], d_data[0.0])

f,p 

#f = 3.40
#p = 0.05
# Out:
# (3.4035654214923707, 0.06545617052172904)

# %%
#Social smoker
grps = pd.unique(data1['Social smoker'].values)
d_data = {grp:data1['Absenteeism time in hours'][data1['Social smoker'] == grp] for grp in grps}
k= len(pd.unique(data1['Social smoker']))
N = len(data1.values)
n = data1.groupby('Social smoker').size()[0]

f,p = stats.f_oneway(d_data[1.0], d_data[0.0])

f,p 

#f = 2.37
#p = 0.12
# Out:
# (2.370717600605327, 0.12405884444173393)

# %%
#Droppong variables
data1 = data1.drop(['Day of the week', 'Seasons', 'Disciplinary failure', 'Education'], axis=1)

# %%
train.shape
# Out:
# (592, 13)

# %%
#NORMALIZATION
    
cnames = ['Transportation expense','Service time', 'Age','Work load Average/day ','Hit target', 'Son','Pet','Body mass index']

for i in cnames:
    print(i)
    data1[i] = (data1[i] - min(data1[i]))/(max(data1[i]) - min(data1[i]))
# Out:
# Transportation expense
# Service time
# Age
# Work load Average/day
# Hit target
# Son
# Pet
# Body mass index

# %%
# MODELING

#Sampling
train, test = train_test_split(data1, test_size = 0.2)

# %%
#DECISION TREE REGRESSION 
from sklearn.cross_validation import train_test_split
from sklearn.tree import DecisionTreeRegressor

# %%
fit = DecisionTreeRegressor(max_depth = 2).fit(train.iloc[:,0:12],train.iloc[:,12])

# %%
prediction_dt = fit.predict(test.iloc[:,0:12])

# %%
#error matrix
from sklearn import metrics

# %%
print('MSE:', metrics.mean_squared_error(test.iloc[:,10], prediction_dt))
print('RMSE:', np.sqrt(metrics.mean_squared_error(test.iloc[:,10], prediction_dt)))

#mse = 19.23
#rmse = 4.38

#accuracy = 100-rmsse = 95.62
# Out:
# MSE: 19.239333020892833
# RMSE: 4.386266410159423

# %%
#RANDOM FOREST REGRESSION
from sklearn.ensemble import RandomForestRegressor

# %%
rf = RandomForestRegressor(n_estimators = 500, random_state = 42).fit(train.iloc[:,0:12],train.iloc[:,12])

# %%
prediction_rf = rf.predict(test.iloc[:,0:12])

# %%
#error matrix
print('MSE:', metrics.mean_squared_error(test.iloc[:,12], prediction_rf))
print('RMSE:', np.sqrt(metrics.mean_squared_error(test.iloc[:,12], prediction_rf)))

#mse = 8.11
#rmse = 2.84

#accuracy = 97.16
# Out:
# MSE: 8.117834455989026
# RMSE: 2.849181365934613

# %%
#LINEAR REGRESSION
import statsmodels.api as sm

# %%
data1.dtypes
# Out:
# Reason for absence           category
# Month of absence             category
# Transportation expense        float64
# Service time                  float64
# Age                           float64
# Work load Average/day         float64
# Hit target                    float64
# Son                           float64
# Social drinker               category
# Social smoker                category
# Pet                           float64
# Body mass index               float64
# Absenteeism time in hours     float64
# dtype: object

# %%
pd.get_dummies(data1, columns = ['Reason for absence', 'Month of absence', 'Social drinker', 'Social smoker'], drop_first = True)
# Out:
#      Transportation expense  Service time       Age  Work load Average/day   \
# 0                  0.657692      0.521739  0.230769                0.244925
# 1                  0.000000      0.739130  0.884615                0.244925
# 2                  0.234615      0.739130  0.423077                0.244925
# 3                  0.619231      0.565217  0.461538                0.244925
# 4                  0.657692      0.521739  0.230769                0.244925
# 5                  0.234615      0.739130  0.423077                0.244925
# 6                  0.411538      0.086957  0.038462                0.244925
# 7                  0.546154      0.434783  0.346154                0.244925
# 8                  0.411538      0.478261  0.384615                0.424739
# 9                  0.450000      0.565217  0.384615                0.244925
# 10                 0.546154      0.434783  0.346154                0.244925
# ...

# %%
#sampling
train, test = train_test_split(data1, test_size = 0.2)

# %%
model = sm.OLS(train.iloc[:,12],train.iloc[:,0:12].astype(float)).fit()

# %%
model.summary()

#r-square = 0.66
#adj r-sq = 0.65
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                 OLS Regression Results
# ...
# Dep. Variable:     Absenteeism time in hours   R-squared:                       0.664
# Model:                                   OLS   Adj. R-squared:                  0.657
# Method:                        Least Squares   F-statistic:                     95.36
# Date:                       Thu, 16 Aug 2018   Prob (F-statistic):          1.40e-128
# Time:                               13:08:56   Log-Likelihood:                -1517.3
# No. Observations:                        592   AIC:                             3059.
# Df Residuals:                            580   BIC:                             3111.
# Df Model:                                 12
# Covariance Type:                   nonrobust
# ...
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
prediction_lr = model.predict(test.iloc[:,0:12])

# %%
#ERROR METRICS
print('MSE:', metrics.mean_squared_error(test.iloc[:,12], prediction_lr))
print('RMSE:', np.sqrt(metrics.mean_squared_error(test.iloc[:,12], prediction_lr)))

#mse = 10.15
#rmse = 3.18

#accuracy = 100-rmse = 96.82
# Out:
# MSE: 10.156199121192424
# RMSE: 3.1868792134614115

# %%
#we fix Random Forest as our model (accuracy = 97.16)

# %%
#LOSSES EVERY MONTH
new = copy1[['Month of absence','Service time','Work load Average/day ','Absenteeism time in hours']]

# %%
new["Loss"]=(new['Work load Average/day ']*new['Absenteeism time in hours'])/new['Service time']
# Out:
# C:\Users\dell\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
new["Loss"] = np.round(new["Loss"]).astype('int64')
# Out:
# C:\Users\dell\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
new.head()
# Out:
#    Month of absence  Service time  Work load Average/day   \
# 0               7.0          13.0                239554.0
# 1               7.0          18.0                239554.0
# 2               7.0          18.0                239554.0
# 3               7.0          14.0                239554.0
# 4               7.0          13.0                239554.0
#
#    Absenteeism time in hours   Loss
# 0                        4.0  73709
# 1                        0.0      0
# 2                        2.0  26617
# 3                        4.0  68444
# 4                        2.0  36854

# %%
No_absent = new[new['Month of absence'] == 0]['Loss'].sum()
January = new[new['Month of absence'] == 1]['Loss'].sum()
February = new[new['Month of absence'] == 2]['Loss'].sum()
March = new[new['Month of absence'] == 3]['Loss'].sum()
April = new[new['Month of absence'] == 4]['Loss'].sum()
May = new[new['Month of absence'] == 5]['Loss'].sum()
June = new[new['Month of absence'] == 6]['Loss'].sum()
July = new[new['Month of absence'] == 7]['Loss'].sum()
August = new[new['Month of absence'] == 8]['Loss'].sum()
September = new[new['Month of absence'] == 9]['Loss'].sum()
October = new[new['Month of absence'] == 10]['Loss'].sum()
November = new[new['Month of absence'] == 11]['Loss'].sum()
December = new[new['Month of absence'] == 12]['Loss'].sum()

# %%
record = {'No Absent': No_absent, 'Janaury': January,'Febraury': February,'March': March,
       'April': April, 'May': May,'June': June,'July': July,
       'August': August,'September': September,'October': October,'November': November,
       'December': December}

# %%
WorkLoss = pd.DataFrame.from_dict(record, orient='index')

# %%
WorkLoss.rename(index=str, columns={0: "Work Load Loss/Month"})
# Out:
#            Work Load Loss/Month
# No Absent                     0
# Janaury                 6312633
# Febraury                8268542
# March                  16552699
# April                  10999489
# May                    10181350
# June                   14569137
# July                   19212717
# August                  9415534
# September               6891606
# October                 9647002
# November               12902373
# December               12342048
